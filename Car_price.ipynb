# %% [markdown]
# <a href="https://colab.research.google.com/github/Darius-BOUL/Car_prices/blob/main/Car_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Comprendre le marché des revendeur automobile aux USA.
# Ce jeu de données vient au format CSV.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/car_prices.csv")

# %% [markdown]
# La question est de savoir quel marque de véhicules a été la plus vendue en 2015 ?

# %% [markdown]
# On débute par nettoyer les données, si nécessaire.

# %% [markdown]
# On commence par inspecter les premières lignes et les valeurs manquantes :

# %%
df.head(10)
# Out:
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# 7  2014  Chevrolet                Cruze                        1LT
# 8  2014       Audi                   A4  2.0T Premium Plus quattro
# 9  2014  Chevrolet               Camaro                         LT
#
#           body transmission                vin state  condition  odometer  \
# 0          SUV    automatic  5xyktca69fg566472    ca        5.0   16639.0
# 1          SUV    automatic  5xyktca69fg561319    ca        5.0    9393.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %% [markdown]
# Si nécessaire, on traite les valeurs manquantes en fonction de leur importance

# %%
df_clean = df.dropna()

# %%
df_clean.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %% [markdown]
# Filtrer les ventes de 2015

# %%
df_2015 = df[df["year"] == 2015]
df_2015.head()
# Out:
#     year    make    model   trim   body transmission                vin state  \
# 0   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg566472    ca
# 1   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg561319    ca
# 3   2015   Volvo      S60     T5  Sedan    automatic  yv1612tb4f1310987    ca
# 5   2015  Nissan   Altima  2.5 S  Sedan    automatic  1n4al3ap1fn326013    ca
# 11  2015     Kia   Optima     LX  Sedan    automatic  5xxgm4a73fg353538    ca
#
#     condition  odometer  color interior  \
# 0         5.0   16639.0  white    black
# 1         5.0    9393.0  white    beige
# 3        41.0   14282.0  white    black
# 5         1.0    5554.0   gray    black
# 11       48.0    2034.0    red      tan
#
#                                                seller      mmr  sellingprice  \
# 0                             kia motors america  inc  20500.0       21500.0
# 1                             kia motors america  inc  20800.0       21500.0
# ...

# %% [markdown]
# Identifiant de la marque la plus vendue

# %%
marque_plus_vendue = df_2015["make"].value_counts().idxmax()
count = df_2015["make"].value_counts().max()

print(f"Avec {count} ventes, la {marque_plus_vendue} est la marque la plus vendue en 2015")
# Out:
# Avec 1482 ventes, la Kia est la marque la plus vendue en 2015

# %% [markdown]
# Visualiser les ventes par marque.

# %%
# Top 10 des marques les plus vendues
top_makes = df_2015["make"].value_counts().head(10)

plt.figure(figsize=(12,6))
top_makes.plot(kind="bar", color="skyblue")
plt.xlabel("Marque")
plt.ylabel("Nombre de ventes")
plt.title("Top 10 des marques les plus vendues en 2015")
plt.xticks(rotation=45)
plt.show()
